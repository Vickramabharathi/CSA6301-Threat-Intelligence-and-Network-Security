# %% [markdown]
# <a href="https://colab.research.google.com/github/Vickramabharathi/CSA6301-Threat-Intelligence-and-Network-Security/blob/main/Experiment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket

def scan_port(host, port):
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.settimeout(0.5)

    result = s.connect_ex((host, port))

    s.close()

    return result == 0

# Scan your own machine (localhost)
target = "127.0.0.1"

ports = [21, 22, 23, 25, 80, 443, 3306, 8080]

print(f"Scanning {target} ...")

for port in ports:
    status = "OPEN" if scan_port(target, port) else "CLOSED"
    print(f"Port {port}: {status}")
# Out:
# Scanning 127.0.0.1 ...
# Port 21: CLOSED
# Port 22: CLOSED
# Port 23: CLOSED
# Port 25: CLOSED
# Port 80: CLOSED
# Port 443: CLOSED
# Port 3306: CLOSED
# Port 8080: OPEN
