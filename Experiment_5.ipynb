# %% [markdown]
# <a href="https://colab.research.google.com/github/Vickramabharathi/CSA6301-Threat-Intelligence-and-Network-Security/blob/main/Experiment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DNS Lookup (OSINT Basics)
import socket

domains = [
    "www.google.com",
    "www.python.org",
    "notarealdomain12345.com"
]

for d in domains:
    try:
        ip = socket.gethostbyname(d)
        print(f"{d:30s} -> {ip}")
    except socket.gaierror:
        print(f"{d:30s} -> Could not resolve (invalid/unreachable)")
# Out:
# www.google.com                 -> 142.251.152.119
# www.python.org                 -> 151.101.0.223
# notarealdomain12345.com        -> Could not resolve (invalid/unreachable)
